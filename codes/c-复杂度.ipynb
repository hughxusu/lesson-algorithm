# %%
# %%time
for a in range(1001):
    for b in range(1001):
        c = 1000 - a - b
        if a**2 + b**2 == c**2:
            print(a, b, c)
# Out:
# 0 500 500
# 200 375 425
# 375 200 425
# 500 0 500
# CPU times: user 84.9 ms, sys: 1.45 ms, total: 86.4 ms
# Wall time: 85.9 ms
