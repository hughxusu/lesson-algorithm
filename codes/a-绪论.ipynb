# %%
# %%time
for a in range(1001):
    for b in range(1001):
        for c in range(1001):
            if a**2 + b**2 == c**2 and a + b + c == 1000:
                print(a, b, c)
# Out:
# 0 500 500
# 200 375 425
# 375 200 425
# 500 0 500
# CPU times: user 53.8 s, sys: 236 ms, total: 54 s
# Wall time: 54.1 s
